# %%
# !pip install --upgrade ibm-watsonx-ai
from ibm_watsonx_ai.foundation_models import Model
parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 100
}

model = Model(
    model_id="granite-13b-instruct-v2",
    params=parameters,
    project_id="ce7c019d-e903-4766-aee3-b3e3c15574c9"
)
prompt = "Explain the concept of AI to a 5-year-old kid."

response = model.generate(prompt)
print("Generated Text:", response)
# Out:
# Requirement already satisfied: ibm-watsonx-ai in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (1.3.26)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (2.32.2)
# Requirement already satisfied: httpx<0.29,>=0.27 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (0.28.1)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (1.26.19)
# Requirement already satisfied: pandas<2.3.0,>=0.24.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (2.1.4)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (2025.4.26)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (0.8.10)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (23.2)
# Requirement already satisfied: ibm-cos-sdk<2.15.0,>=2.12.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai) (2.13.4)
# Requirement already satisfied: anyio in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai) (0.16.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.13.4)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.13.4)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk-core==2.13.4->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->ibm-watsonx-ai) (2.0.4)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from lomond->ibm-watsonx-ai) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai) (1.3.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       2 from ibm_watsonx_ai.foundation_models import Model
#       3 parameters = {
#       4     "decoding_method": "greedy",
#       5     "max_new_tokens": 100
#       6 }
# ----> 8 model = Model(
#       9     model_id="granite-13b-instruct-v2",
#      10     params=parameters,
#      11     project_id="ce7c019d-e903-4766-aee3-b3e3c15574c9"
#      12 )
#      13 prompt = "Explain the concept of AI to a 5-year-old kid."
#      15 response = model.generate(prompt)
#
# TypeError: Model.__init__() missing 1 required positional argument: 'credentials'

# %%
credentials = {
    "url": "https://eu-de.ml.cloud.ibm.com",  # because you are using Frankfurt region
    "apikey": "2-_Znw1m23l5wpIA38xc2NElPo4UC6L79JqnuJTxNoY3"
}
from ibm_watsonx_ai.foundation_models import Model

parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 100
}

model = Model(
    model_id="granite-13b-instruct-v2",
    params=parameters,
    project_id="ce7c019d-e903-4766-aee3-b3e3c15574c9",
    credentials=credentials   # This is the missing argument you got an error for earlier
)

prompt = "Explain the concept of AI to a 5-year-old kid."
response = model.generate(prompt)
print("Generated Text:", response)
# Out:
# /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/model.py:105: DeprecationWarning: The `Model` class is deprecated and will be removed in a future release. Please use the `ModelInference` class instead. To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`.
#   warn(model_class_deprecated_warning, category=DeprecationWarning)
# Failure during Get available foundation models. (GET https://eu-de.ml.cloud.ibm.com/ml/v1/foundation_model_specs?version=2025-06-11&project_id=ce7c019d-e903-4766-aee3-b3e3c15574c9&filters=function_text_generation%2C%21lifecycle_withdrawn%3Aand&limit=200)
# Status code: 403, body: {"errors":[{"code":"no_associated_service_instance_error","message":"project_id ce7c019d-e903-4766-aee3-b3e3c15574c9 is not associated with a WML instance","more_info":"https://cloud.ibm.com/apidocs/watsonx-ai#list-foundation-model-specs"}],"trace":"04b399bb16b96c3e931c0c6502384faf","status_code":403}
# Unable to get model specifications from url: https://eu-de.ml.cloud.ibm.com
# Reason: Failure during Get available foundation models. (GET https://eu-de.ml.cloud.ibm.com/ml/v1/foundation_model_specs?version=2025-06-11&project_id=ce7c019d-e903-4766-aee3-b3e3c15574c9&filters=function_text_generation%2C%21lifecycle_withdrawn%3Aand&limit=200)
# Status code: 403, body: {"errors":[{"code":"no_associated_service_instance_error","message":"project_id ce7c019d-e903-4766-aee3-b3e3c15574c9 is not associated with a WML instance","more_info":"https://cloud.ibm.com/apidocs/watsonx-ai#list-foundation-model-specs"}],"trace":"04b399bb16b96c3e931c0c6502384faf","status_code":403}
# ---------------------------------------------------------------------------
# ApiRequestFailure                         Traceback (most recent call last)
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models_manager.py:94, in FoundationModelsManager._get_spec(self, url, operation_name, error_msg_id, model_id, limit, filters, asynchronous, get_all, tech_preview)
#      93     else:
# ---> 94         return self._get_with_or_without_limit(
#      95             url=url,
#      96             limit=limit,
#      97             op_name=operation_name,
#      98             query_params=params,
#      99             _async=asynchronous,
#     100             _all=get_all,
#     101             skip_space_project_chk=True,
#     102         )
#     103 except WMLClientError as e:
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/wml_resource.py:535, in WMLResource._get_with_or_without_limit(self, url, limit, op_name, summary, pre_defined, revision, skip_space_project_chk, query_params, _async, _all, _filter_func, _silent_response_logging)
#     527 response_get = request_handler.get(
#     528     url=url,
#     529     headers=self._client._get_headers(),
#     530     params=params,
#     531 )
#     533 result = cast(
#     534     dict,
# --> 535     self._handle_response(
#     536         200,
#     537         op_name,
#     538         response_get,
#     539         _silent_response_logging=_silent_response_logging,
#     540     ),
#     541 )
#     542 if "resources" in result:
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/wml_resource.py:167, in WMLResource._handle_response(self, expected_status_code, operationName, response, json_response, _silent_response_logging, _field_to_hide)
#     166 else:
# --> 167     raise ApiRequestFailure(
#     168         "Failure during {}.".format(operationName),
#     169         response,
#     170     )
#
# ApiRequestFailure: Failure during Get available foundation models. (GET https://eu-de.ml.cloud.ibm.com/ml/v1/foundation_model_specs?version=2025-06-11&project_id=ce7c019d-e903-4766-aee3-b3e3c15574c9&filters=function_text_generation%2C%21lifecycle_withdrawn%3Aand&limit=200)
# Status code: 403, body: {"errors":[{"code":"no_associated_service_instance_error","message":"project_id ce7c019d-e903-4766-aee3-b3e3c15574c9 is not associated with a WML instance","more_info":"https://cloud.ibm.com/apidocs/watsonx-ai#list-foundation-model-specs"}],"trace":"04b399bb16b96c3e931c0c6502384faf","status_code":403}
#
# During handling of the above exception, another exception occurred:
#
# WMLClientError                            Traceback (most recent call last)
# Cell In[2], line 12
#       5 from ibm_watsonx_ai.foundation_models import Model
#       7 parameters = {
#       8     "decoding_method": "greedy",
#       9     "max_new_tokens": 100
#      10 }
# ---> 12 model = Model(
#      13     model_id="granite-13b-instruct-v2",
#      14     params=parameters,
#      15     project_id="ce7c019d-e903-4766-aee3-b3e3c15574c9",
#      16     credentials=credentials   # This is the missing argument you got an error for earlier
#      17 )
#      19 prompt = "Explain the concept of AI to a 5-year-old kid."
#      20 response = model.generate(prompt)
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/model.py:107, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     100     model_class_deprecated_warning = (
#     101         "The `Model` class is deprecated and will be removed in a future release. "
#     102         "Please use the `ModelInference` class instead. "
#     103         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     104     )
#     105     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 107 ModelInference.__init__(
#     108     self,
#     109     model_id=model_id,
#     110     credentials=credentials,
#     111     params=params,
#     112     project_id=project_id,
#     113     space_id=space_id,
#     114     verify=verify,
#     115     validate=validate,
#     116 )
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/inference/model_inference.py:222, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, persistent_connection, max_retries, delay_time, retry_status_codes)
#     220 self._inference: BaseModelInference
#     221 if self.model_id:
# --> 222     self._inference = FMModelInference(
#     223         model_id=self.model_id,
#     224         api_client=self._client,
#     225         params=self.params,
#     226         validate=validate,
#     227         persistent_connection=persistent_connection,
#     228         max_retries=max_retries,
#     229         delay_time=delay_time,
#     230         retry_status_codes=retry_status_codes,
#     231     )
#     232 else:
#     233     self.deployment_id = cast(str, self.deployment_id)
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/inference/fm_model_inference.py:71, in FMModelInference.__init__(self, model_id, api_client, params, validate, persistent_connection, max_retries, delay_time, retry_status_codes)
#      68 model_specs: dict = dict()
#      70 if self._client._use_fm_ga_api:
# ---> 71     model_specs = self._client.foundation_models.get_model_specs()  # type: ignore[assignment]
#      72 else:
#      73     with catch_warnings():
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models_manager.py:148, in FoundationModelsManager.get_model_specs(self, model_id, limit, asynchronous, get_all, **kwargs)
#     112 def get_model_specs(
#     113     self,
#     114     model_id: str | None = None,
#    (...)
#     118     **kwargs: Any,
#     119 ) -> dict | Generator | None:
#     120     """
#     121     Retrieves a list of specifications for a deployed foundation model.
#     122
#    (...)
#     146         client.foundation_models.get_model_specs(model_id="google/flan-ul2")
#     147     """
# --> 148     return self._get_spec(
#     149         url=self._client._href_definitions.get_fm_specifications_href(),
#     150         operation_name="Get available foundation models",
#     151         error_msg_id="fm_prompt_tuning_no_model_specs",
#     152         filters=(
#     153             None
#     154             if self._client.CPD_version < 5.0
#     155             else "function_text_generation,!lifecycle_withdrawn:and"
#     156         ),
#     157         model_id=model_id,
#     158         limit=limit,
#     159         asynchronous=asynchronous,
#     160         get_all=get_all,
#     161         tech_preview=kwargs.get("tech_preview", False),
#     162     )
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models_manager.py:104, in FoundationModelsManager._get_spec(self, url, operation_name, error_msg_id, model_id, limit, filters, asynchronous, get_all, tech_preview)
#      94         return self._get_with_or_without_limit(
#      95             url=url,
#      96             limit=limit,
#    (...)
#     101             skip_space_project_chk=True,
#     102         )
#     103 except WMLClientError as e:
# --> 104     raise WMLClientError(
#     105         Messages.get_message(
#     106             self._client.credentials.url,
#     107             message_id=error_msg_id,
#     108         ),
#     109         e,
#     110     )
#
# WMLClientError: Unable to get model specifications from url: https://eu-de.ml.cloud.ibm.com
# Reason: Failure during Get available foundation models. (GET https://eu-de.ml.cloud.ibm.com/ml/v1/foundation_model_specs?version=2025-06-11&project_id=ce7c019d-e903-4766-aee3-b3e3c15574c9&filters=function_text_generation%2C%21lifecycle_withdrawn%3Aand&limit=200)
# Status code: 403, body: {"errors":[{"code":"no_associated_service_instance_error","message":"project_id ce7c019d-e903-4766-aee3-b3e3c15574c9 is not associated with a WML instance","more_info":"https://cloud.ibm.com/apidocs/watsonx-ai#list-foundation-model-specs"}],"trace":"04b399bb16b96c3e931c0c6502384faf","status_code":403}

# %%
credentials = {
    "url": "https://eu-de.ml.cloud.ibm.com",  # because you are using Frankfurt region
    "apikey": "2-_Znw1m23l5wpIA38xc2NElPo4UC6L79JqnuJTxNoY3"
}
from ibm_watsonx_ai.foundation_models import Model

parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 100
}

model = Model(
    model_id="granite-13b-instruct-v2",
    params=parameters,
    project_id="ce7c019d-e903-4766-aee3-b3e3c15574c9",
    credentials=credentials   # This is the missing argument you got an error for earlier
)

prompt = "Explain the concept of AI to a 5-year-old kid."
response = model.generate(prompt)
print("Generated Text:", response)
# Out:
# /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/model.py:105: DeprecationWarning: The `Model` class is deprecated and will be removed in a future release. Please use the `ModelInference` class instead. To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`.
#   warn(model_class_deprecated_warning, category=DeprecationWarning)
# Model 'granite-13b-instruct-v2' is not supported for this environment. Supported models: ['core42/jais-13b-chat', 'google/flan-t5-xl', 'google/flan-t5-xxl', 'google/flan-ul2', 'ibm/granite-13b-instruct-v2', 'ibm/granite-20b-code-instruct', 'ibm/granite-3-2b-instruct', 'ibm/granite-3-3-8b-instruct', 'ibm/granite-3-8b-instruct', 'ibm/granite-34b-code-instruct', 'meta-llama/llama-2-13b-chat', 'meta-llama/llama-3-2-11b-vision-instruct', 'meta-llama/llama-3-2-90b-vision-instruct', 'meta-llama/llama-3-3-70b-instruct', 'meta-llama/llama-4-maverick-17b-128e-instruct-fp8', 'mistralai/mistral-large', 'mistralai/mistral-small-24b-instruct-2501', 'mistralai/mistral-small-3-1-24b-instruct-2503', 'mistralai/mixtral-8x7b-instruct-v01', 'mistralai/pixtral-12b', 'sdaia/allam-1-13b-instruct']
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# Cell In[1], line 12
#       5 from ibm_watsonx_ai.foundation_models import Model
#       7 parameters = {
#       8     "decoding_method": "greedy",
#       9     "max_new_tokens": 100
#      10 }
# ---> 12 model = Model(
#      13     model_id="granite-13b-instruct-v2",
#      14     params=parameters,
#      15     project_id="ce7c019d-e903-4766-aee3-b3e3c15574c9",
#      16     credentials=credentials   # This is the missing argument you got an error for earlier
#      17 )
#      19 prompt = "Explain the concept of AI to a 5-year-old kid."
#      20 response = model.generate(prompt)
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/model.py:107, in Model.__init__(self, model_id, credentials, params, project_id, space_id, verify, validate)
#     100     model_class_deprecated_warning = (
#     101         "The `Model` class is deprecated and will be removed in a future release. "
#     102         "Please use the `ModelInference` class instead. "
#     103         "To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`."
#     104     )
#     105     warn(model_class_deprecated_warning, category=DeprecationWarning)
# --> 107 ModelInference.__init__(
#     108     self,
#     109     model_id=model_id,
#     110     credentials=credentials,
#     111     params=params,
#     112     project_id=project_id,
#     113     space_id=space_id,
#     114     verify=verify,
#     115     validate=validate,
#     116 )
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/inference/model_inference.py:222, in ModelInference.__init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client, validate, persistent_connection, max_retries, delay_time, retry_status_codes)
#     220 self._inference: BaseModelInference
#     221 if self.model_id:
# --> 222     self._inference = FMModelInference(
#     223         model_id=self.model_id,
#     224         api_client=self._client,
#     225         params=self.params,
#     226         validate=validate,
#     227         persistent_connection=persistent_connection,
#     228         max_retries=max_retries,
#     229         delay_time=delay_time,
#     230         retry_status_codes=retry_status_codes,
#     231     )
#     232 else:
#     233     self.deployment_id = cast(str, self.deployment_id)
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/inference/fm_model_inference.py:101, in FMModelInference.__init__(self, model_id, api_client, params, validate, persistent_connection, max_retries, delay_time, retry_status_codes)
#      98                 break
#     100     if not self._tech_preview:
# --> 101         raise WMLClientError(
#     102             error_msg=f"Model '{self.model_id}' is not supported for this environment. "
#     103             f"Supported models: {supported_models}"
#     104         )
#     106 # check if model is in constricted mode
#     107 _check_model_state(
#     108     self._client,
#     109     self.model_id,
#     110     tech_preview=self._tech_preview,
#     111     model_specs=model_specs,
#     112 )
#
# WMLClientError: Model 'granite-13b-instruct-v2' is not supported for this environment. Supported models: ['core42/jais-13b-chat', 'google/flan-t5-xl', 'google/flan-t5-xxl', 'google/flan-ul2', 'ibm/granite-13b-instruct-v2', 'ibm/granite-20b-code-instruct', 'ibm/granite-3-2b-instruct', 'ibm/granite-3-3-8b-instruct', 'ibm/granite-3-8b-instruct', 'ibm/granite-34b-code-instruct', 'meta-llama/llama-2-13b-chat', 'meta-llama/llama-3-2-11b-vision-instruct', 'meta-llama/llama-3-2-90b-vision-instruct', 'meta-llama/llama-3-3-70b-instruct', 'meta-llama/llama-4-maverick-17b-128e-instruct-fp8', 'mistralai/mistral-large', 'mistralai/mistral-small-24b-instruct-2501', 'mistralai/mistral-small-3-1-24b-instruct-2503', 'mistralai/mixtral-8x7b-instruct-v01', 'mistralai/pixtral-12b', 'sdaia/allam-1-13b-instruct']

# %%
credentials = {
    "url": "https://eu-de.ml.cloud.ibm.com",  # because you are using Frankfurt region
    "apikey": "2-_Znw1m23l5wpIA38xc2NElPo4UC6L79JqnuJTxNoY3"
}
from ibm_watsonx_ai.foundation_models import Model

parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 100
}

model = Model(
    model_id="ibm/granite-13b-instruct-v2",
    params=parameters,
    project_id="ce7c019d-e903-4766-aee3-b3e3c15574c9",
    credentials=credentials   # This is the missing argument you got an error for earlier
)

prompt = "Explain the concept of AI to a 5-year-old kid."
response = model.generate(prompt)
print("Generated Text:", response)
# Out:
# /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/model.py:105: DeprecationWarning: The `Model` class is deprecated and will be removed in a future release. Please use the `ModelInference` class instead. To update your imports, use: `from ibm_watsonx_ai.foundation_models import ModelInference`.
#   warn(model_class_deprecated_warning, category=DeprecationWarning)
# /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages/ibm_watsonx_ai/foundation_models/utils/utils.py:436: LifecycleWarning: Model 'ibm/granite-13b-instruct-v2' is in deprecated state from 2025-06-18 until 2025-10-15. IDs of alternative models: ibm/granite-3-3-8b-instruct. Further details: https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-model-lifecycle.html?context=wx&audience=wdp
#   warn(model_state_warning, category=LifecycleWarning)
# Generated Text: {'model_id': 'ibm/granite-13b-instruct-v2', 'created_at': '2025-06-19T11:42:57.485Z', 'results': [{'generated_text': 'Artificial intelligence is a branch of computer science that focuses on creating intelligent machines that can think and act like humans.', 'generated_token_count': 24, 'input_token_count': 15, 'stop_reason': 'eos_token'}], 'system': {'warnings': [{'message': "Model 'ibm/granite-13b-instruct-v2' is in deprecated state from 2025-06-18. It will be in withdrawn state from 2025-10-15. IDs of alternative models: ibm/granite-3-3-8b-instruct.", 'id': 'deprecation_warning', 'more_info': 'https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-model-lifecycle.html?context=wx&audience=wdp'}, {'message': "This API is deprecated. Please use '/text/chat' instead.", 'id': 'api_deprecation'}]}}

# %%
from ibm_watsonx_ai.foundation_models import ModelInference

model_id = "ibm/granite-3-8b-instruct"  
project_id = "ce7c019d-e903-4766-aee3-b3e3c15574c9" 

credentials = {
    "url": "https://eu-de.ml.cloud.ibm.com",  
    "apikey": "2-_Znw1m23l5wpIA38xc2NElPo4UC6L79JqnuJTxNoY3"  
}

model = ModelInference(
    model_id=model_id,
    params={"decoding_method": "greedy"},  
    project_id=project_id,
    credentials=credentials
)

prompt = "Explain the concept of AI to a 5-year-old-kid"

response = model.generate(prompt)

print("Generated Text:", response)
# Out:
# Generated Text: {'model_id': 'ibm/granite-3-8b-instruct', 'model_version': '1.1.0', 'created_at': '2025-06-19T11:53:44.886Z', 'results': [{'generated_text': '.\n\nImagine if your toys could think and learn all by themselves, just like you', 'generated_token_count': 20, 'input_token_count': 15, 'stop_reason': 'max_tokens'}], 'system': {'warnings': [{'message': "The value of 'parameters.max_new_tokens' for this model was set to value 20", 'id': 'unspecified_max_new_tokens', 'additional_properties': {'limit': 0, 'new_value': 20, 'parameter': 'parameters.max_new_tokens', 'value': 0}}, {'message': "This API is deprecated. Please use '/text/chat' instead.", 'id': 'api_deprecation'}]}}
